# %%
#Linear regression is basically assuming linear relation between x and y

#It tries to get best possible line or the best possible answer for given set of data
#let consider y=mx+c    It will try to predict one of the best value of m and c for any x and y

# %%
import numpy as np
data=np.loadtxt("data.csv",delimiter=",")

# %%
x=data[:,0].reshape(-1,1)
y=data[:,1]

x.shape
# Out:
# (100, 1)

# %%
from sklearn import model_selection

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression

alg1=LinearRegression()
alg1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
alg1.coef_
#this is basically m
# Out:
# array([1.35635955])

# %%
alg1.intercept_
#this is c
# Out:
# 5.868126264222923

# %%
import matplotlib.pyplot as plt

m=alg1.coef_[0]
c=alg1.intercept_

x_line=np.arange(30,70,0.1)
y_line=m*x_line+c

train_1d=X_train.reshape(75)
plt.scatter(X_train,Y_train)
plt.plot(x_line,y_line,"r")
plt.show()

# %%
import matplotlib.pyplot as plt

m=alg1.coef_[0]
c=alg1.intercept_

x_line=np.arange(30,70,0.1)
y_line=m*x_line+c

train_1d=X_test.reshape(25)
plt.scatter(X_test,Y_test)
plt.plot(x_line,y_line,"r")
plt.show()

# %%
#score coefficient of determination- It is to compare how close or far is the predicted value to the real value

#score=1-y/v

#y==summation of (yitrue-yipredicted)^2
#v==summation of (yitrue-ytruemean)^2

#value between 0-1

# %%
score_test=alg1.score(X_test,Y_test)
score_training=alg1.score(X_train,Y_train)
print(score_test,score_training)
# Out:
# 0.5608247533302152 0.6058970445368881
